# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
from MyStyleTranferMRF import main
# Out:
# Using gpu device 0: GeForce GTX 1070 (CNMeM is enabled with initial size: 90.0% of memory, cuDNN 5105)

# %%
main()
# Out:
# ('starting time is: ', datetime.datetime(2016, 12, 19, 2, 15, 49, 428080))
# Layers.py:94: UserWarning: DEPRECATION: the 'ds' parameter is not going to exist anymore as it is going to be replaced by the parameter 'ws'.
#   mode=self.mode
# ('content_loss: ', array(0.0, dtype=float32))
# ('denominator shape', (900, 900), 'numerator shape', (900, 900))
# ('index of the best match patch in style feature map', array([330, 331, 302, 204, 205,   6,   7,   7,  38,  39,  12,  13,  13,
#         13,  13,  13,  14,  15,  13,  13,  14,  15,  15,  16,  83,  23,
#         24,  25, 178, 179, 360, 331, 302, 234,  94,  65,  66,  67,  68,
#         69,  70,  43,  43,  43,  43,  43,  44,  45,  45,  44,  44,  45,
#         79, 143, 144, 175, 206, 207, 208, 179, 360, 331, 302, 213, 124,
#         95,  96,  97,  98,  99, 100,  73,  73,  73,  73,  74,  74,  75,
#         75,  74,  75,  75, 109, 173, 174, 205, 215, 216, 396, 299, 360,
# ...
